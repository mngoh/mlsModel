# %% [markdown]
# ## 1_ed
# ### Purpose: Analyzed scraped web data for MLS team from 2010 - 2017
# ### 09/28/2023

# %% [markdown]
# ***

# %%
# Imports
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from funcs import b_plot, l_plot, s_plot

# %%
# Load Data 
df = pd.read_csv('mls_data_2010_2017.csv')

# %%
# Quick Info 
df.columns
# Out:
# Index(['Squad', '# Pl', 'Age', 'Poss', 'MP', 'Starts', 'Min', '90s', 'Gls',
#        'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'Gls.1', 'Ast.1',
#        'G+A.1', 'G-PK.1', 'G+A-PK', 'year'],
#       dtype='object')

# %% [markdown]
# # Trend Graphs

# %%
# Create a barplot using Seaborn
line_plots = ['Age', 'Gls', 'Ast']
for y in line_plots:    
    l_plot(df, x = 'year', y=y)

# %% [markdown]
# # Scatter Plots

# %%
# Scatter Plots with Gls 
for y in df.columns:
    s_plot(df, x= 'Gls', y=y)

# %% [markdown]
# # How Has DC United Performed Over the Years?

# %%
# Get By DCU 
dcu = df[df['Squad'] == 'D.C. United']
dcu = dcu[['Gls', 'Ast', 'year', 'Age']]

# %%
# Plots 
for y in dcu[['Gls', 'Ast', 'Age']].columns:
    l_plot(df=dcu, x = 'year', y=y)
