# %% [markdown]
# ## 1_ed
# ### Purpose: Analyzed scraped web data for MLS team from 2010 - 2017
# ### 09/28/2023

# %% [markdown]
# ***

# %%
# Imports
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from funcs import b_plot

# %%
# Load Data 
df = pd.read_csv('mls_data_2010_2017.csv')

# %%
# Quick Info 
df.head(3)
# Out:
#              Squad  # Pl   Age  Poss  MP  Starts     Min   90s  Gls  Ast  ...
# 0     Chicago Fire    28  26.7   NaN  30     330  2700.0  30.0   35   23  ...  \
# 1       Chivas USA    31  26.7   NaN  30     330  2700.0  30.0   30   20  ...
# 2  Colorado Rapids    23  27.1   NaN  30     330  2700.0  30.0   41   26  ...
#
#    PK  PKatt  CrdY  CrdR  Gls.1  Ast.1  G+A.1  G-PK.1  G+A-PK  year
# 0   2      2  40.0   3.0   1.17   0.77   1.93    1.10    1.87  2010
# 1   1      1  47.0   2.0   1.00   0.67   1.67    0.97    1.63  2010
# 2   4      4  49.0   2.0   1.37   0.87   2.23    1.23    2.10  2010
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Visualize

# %%
# Create a barplot using Seaborn
b_plot(df, x = 'Squad', y='Age')
